# %%
import pandas as pd

# %%
df = pd.read_csv('studentDepression.csv')

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
df[['Age','CGPA']]
# Out:
#         Age  CGPA
# 0      33.0  8.97
# 1      24.0  5.90
# 2      31.0  7.03
# 3      28.0  5.59
# 4      25.0  8.13
# ...     ...   ...
# 27896  27.0  5.75
# 27897  27.0  9.40
# 27898  31.0  6.61
# 27899  18.0  6.88
# 27900  27.0  9.24
#
# [27901 rows x 2 columns]

# %%
df.loc[1:5]
# Out:
#    id  Gender   Age       City Profession  Academic Pressure  Work Pressure  \
# 1   8  Female  24.0  Bangalore    Student                2.0            0.0
# 2  26    Male  31.0   Srinagar    Student                3.0            0.0
# 3  30  Female  28.0   Varanasi    Student                3.0            0.0
# 4  32  Female  25.0     Jaipur    Student                4.0            0.0
# 5  33    Male  29.0       Pune    Student                2.0            0.0
#
#    CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# 1  5.90                 5.0               0.0          5-6 hours
# 2  7.03                 5.0               0.0  Less than 5 hours
# 3  5.59                 2.0               0.0          7-8 hours
# 4  8.13                 3.0               0.0          5-6 hours
# 5  5.70                 3.0               0.0  Less than 5 hours
#
#   Dietary Habits  Degree Have you ever had suicidal thoughts ?  \
# ...

# %%
df.iloc[1:5]
# Out:
#    id  Gender   Age       City Profession  Academic Pressure  Work Pressure  \
# 1   8  Female  24.0  Bangalore    Student                2.0            0.0
# 2  26    Male  31.0   Srinagar    Student                3.0            0.0
# 3  30  Female  28.0   Varanasi    Student                3.0            0.0
# 4  32  Female  25.0     Jaipur    Student                4.0            0.0
#
#    CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# 1  5.90                 5.0               0.0          5-6 hours
# 2  7.03                 5.0               0.0  Less than 5 hours
# 3  5.59                 2.0               0.0          7-8 hours
# 4  8.13                 3.0               0.0          5-6 hours
#
#   Dietary Habits  Degree Have you ever had suicidal thoughts ?  \
# 1       Moderate     BSc                                    No
# 2        Healthy      BA                                    No
# 3       Moderate     BCA                                   Yes
# ...

# %%
df[df['Age']>30]
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 2          26   Male  31.0       Srinagar    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 11         91   Male  33.0       Vadodara    Student                3.0
# 26        186   Male  31.0      Ahmedabad    Student                2.0
# ...       ...    ...   ...            ...        ...                ...
# 27876  140536   Male  33.0         Nagpur    Student                1.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27889  140631   Male  33.0      Ahmedabad    Student                1.0
# 27895  140684   Male  31.0        Lucknow    Student                2.0
# 27898  140689   Male  31.0      Faridabad    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.count()
# Out:
# id                                       27901
# Gender                                   27901
# Age                                      27901
# City                                     27901
# Profession                               27901
# Academic Pressure                        27901
# Work Pressure                            27901
# CGPA                                     27901
# Study Satisfaction                       27901
# Job Satisfaction                         27901
# Sleep Duration                           27901
# Dietary Habits                           27901
# Degree                                   27901
# Have you ever had suicidal thoughts ?    27901
# Work/Study Hours                         27901
# Financial Stress                         27898
# Family History of Mental Illness         27901
# Depression                               27901
# dtype: int64

# %%
df[df['Age']>30].count()
# Out:
# id                                       6099
# Gender                                   6099
# Age                                      6099
# City                                     6099
# Profession                               6099
# Academic Pressure                        6099
# Work Pressure                            6099
# CGPA                                     6099
# Study Satisfaction                       6099
# Job Satisfaction                         6099
# Sleep Duration                           6099
# Dietary Habits                           6099
# Degree                                   6099
# Have you ever had suicidal thoughts ?    6099
# Work/Study Hours                         6099
# Financial Stress                         6098
# Family History of Mental Illness         6099
# Depression                               6099
# dtype: int64

# %%
df.query('Age > 30')
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 2          26   Male  31.0       Srinagar    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 11         91   Male  33.0       Vadodara    Student                3.0
# 26        186   Male  31.0      Ahmedabad    Student                2.0
# ...       ...    ...   ...            ...        ...                ...
# 27876  140536   Male  33.0         Nagpur    Student                1.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27889  140631   Male  33.0      Ahmedabad    Student                1.0
# 27895  140684   Male  31.0        Lucknow    Student                2.0
# 27898  140689   Male  31.0      Faridabad    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.isnull()
# Out:
#           id  Gender    Age   City  Profession  Academic Pressure  \
# 0      False   False  False  False       False              False
# 1      False   False  False  False       False              False
# 2      False   False  False  False       False              False
# 3      False   False  False  False       False              False
# 4      False   False  False  False       False              False
# ...      ...     ...    ...    ...         ...                ...
# 27896  False   False  False  False       False              False
# 27897  False   False  False  False       False              False
# 27898  False   False  False  False       False              False
# 27899  False   False  False  False       False              False
# 27900  False   False  False  False       False              False
#
#        Work Pressure   CGPA  Study Satisfaction  Job Satisfaction  \
# 0              False  False               False             False
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
#fill missing values with zero
df1 = df.fillna(0)

# %%
#check the changes count 
df1.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
 df.sort_values(by='Age', ascending=False)
# Out:
#            id  Gender   Age      City Profession  Academic Pressure  \
# 9238    46602    Male  59.0    Nashik    Student                1.0
# 2909    14768  Female  58.0   Chennai    Student                4.0
# 14819   74887  Female  56.0  Ludhiana    Student                3.0
# 13499   68441    Male  54.0      Agra    Student                5.0
# 4386    22004  Female  51.0    Bhopal    Student                2.0
# ...       ...     ...   ...       ...        ...                ...
# 15856   80171    Male  18.0    Jaipur    Student                1.0
# 15870   80239  Female  18.0   Lucknow    Student                3.0
# 15871   80246  Female  18.0    Indore    Student                5.0
# 15873   80270    Male  18.0    Rajkot    Student                4.0
# 22537  113642  Female  18.0  Ludhiana    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9238             0.0  8.14                 1.0               0.0
# ...

# %%
 df.sort_values(by='Age', ascending=False).head()
# Out:
#           id  Gender   Age      City Profession  Academic Pressure  \
# 9238   46602    Male  59.0    Nashik    Student                1.0
# 2909   14768  Female  58.0   Chennai    Student                4.0
# 14819  74887  Female  56.0  Ludhiana    Student                3.0
# 13499  68441    Male  54.0      Agra    Student                5.0
# 4386   22004  Female  51.0    Bhopal    Student                2.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9238             0.0  8.14                 1.0               0.0
# 2909             0.0  8.58                 1.0               0.0
# 14819            0.0  7.94                 5.0               0.0
# 13499            0.0  9.60                 2.0               0.0
# 4386             0.0  8.26                 3.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 9238           5-6 hours      Unhealthy       PhD
# 2909           7-8 hours        Healthy  Class 12
# ...

# %%
 df.sort_values(by='Age', ascending=False).head(10)
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 9238    46602    Male  59.0     Nashik    Student                1.0
# 2909    14768  Female  58.0    Chennai    Student                4.0
# 14819   74887  Female  56.0   Ludhiana    Student                3.0
# 13499   68441    Male  54.0       Agra    Student                5.0
# 4386    22004  Female  51.0     Bhopal    Student                2.0
# 3436    17213    Male  49.0     Nagpur    Student                3.0
# 25202  126970  Female  48.0     Rajkot    Student                3.0
# 13618   69032  Female  48.0  Ghaziabad    Student                3.0
# 27334  137827  Female  48.0      Surat    Student                1.0
# 9006    45393    Male  46.0     Nashik    Student                1.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9238             0.0  8.14                 1.0               0.0
# 2909             0.0  8.58                 1.0               0.0
# ...

# %%
df[['CGPA']].min()
# Out:
# CGPA    0.0
# dtype: float64

# %%
df[['CGPA']].max()
# Out:
# CGPA    10.0
# dtype: float64

# %%
df[['City']].nunique()
# Out:
# City    52
# dtype: int64

# %%
#filter rows where indiduals thought was suicidal

# %%
df[df['Have you ever had suicidal thoughts ?']== 'Yes']
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# 8          59    Male  28.0         Nagpur    Student                3.0
# 9          62    Male  31.0         Nashik    Student                2.0
# ...       ...     ...   ...            ...        ...                ...
# 27894  140681    Male  23.0       Srinagar    Student                3.0
# 27895  140684    Male  31.0        Lucknow    Student                2.0
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#filter for high finacial stress

# %%
df[['Financial Stress']].max()
# Out:
# Financial Stress    5.0
# dtype: float64

# %%
df[df['Financial Stress']>3]
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 3          30  Female  28.0   Varanasi    Student                3.0
# 9          62    Male  31.0     Nashik    Student                2.0
# 14        103  Female  19.0     Kalyan    Student                5.0
# 16        120    Male  25.0     Nashik    Student                5.0
# 22        166  Female  25.0  Ahmedabad    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27883  140584  Female  22.0     Kanpur    Student                4.0
# 27887  140624    Male  32.0     Rajkot    Student                4.0
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27894  140681    Male  23.0   Srinagar    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
df['Have you ever had suicidal thoughts ?'].map({'Yes':1 , 'No' :0 })
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 27896    1
# 27897    0
# 27898    0
# 27899    1
# 27900    1
# Name: Have you ever had suicidal thoughts ?, Length: 27901, dtype: int64

# %%
#select the element in the first row and first column

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.iloc[0,1]
# Out:
# 'Male'

# %%
df.iloc[0,0]
# Out:
# 2

# %%
#find all rows where gender is male and dipression is one

# %%
df[(df['Gender'] == 'Male') & (df['Depression'] == 1)]
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 8          59   Male  28.0         Nagpur    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 10         83   Male  24.0         Nagpur    Student                3.0
# 12         94   Male  27.0         Kalyan    Student                5.0
# ...       ...    ...   ...            ...        ...                ...
# 27881  140564   Male  27.0          Surat    Student                4.0
# 27884  140594   Male  18.0         Meerut    Student                5.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27888  140630   Male  19.0        Kolkata    Student                4.0
# 27900  140699   Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#select first 3 rows of the age and CGPA COLUMN

# %%
df.loc[:2,['Age','CGPA']]
# Out:
#     Age  CGPA
# 0  33.0  8.97
# 1  24.0  5.90
# 2  31.0  7.03

# %%
#change the sleep duration for the person with id = 1 change sleep duration 8 - 9

# %%
if(df['id'] == 2).any():
    df.loc[df['id'] == 2 , 'Sleep Duration'] = '8-9 hours'
    print(df.loc[df['id'] == 2 ])
else:
    print('No row with id == 2')
# Out:
#    id Gender   Age           City Profession  Academic Pressure  \
# 0   2   Male  33.0  Visakhapatnam    Student                5.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0      8-9 hours
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               3.0               1.0                               No
#
#    Depression
# 0           1

# %%
 df.loc[df['id'] == 2 , 'Sleep Duration'] = '8-9 hours'
print(df.loc[df['id'] == 2])
# Out:
#    id Gender   Age           City Profession  Academic Pressure  \
# 0   2   Male  33.0  Visakhapatnam    Student                5.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0      8-9 hours
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               3.0               1.0                               No
#
#    Depression
# 0           1

# %%
#print the 1st and 5th row along with 2nd column

# %%
df.iloc[[0,5],2]
# Out:
# 0    33.0
# 5    29.0
# Name: Age, dtype: float64

# %%
df.loc[[0,5],'Degree']
# Out:
# 0    B.Pharm
# 5        PhD
# Name: Degree, dtype: object

# %%
df['City'].value_counts()
# Out:
# City
# Kalyan                1570
# Srinagar              1372
# Hyderabad             1340
# Vasai-Virar           1290
# Lucknow               1155
# Thane                 1139
# Ludhiana              1111
# Agra                  1094
# Surat                 1078
# Kolkata               1066
# Jaipur                1036
# Patna                 1007
# Visakhapatnam          969
# Pune                   968
# Ahmedabad              951
# Bhopal                 934
# Chennai                885
# Meerut                 825
# Rajkot                 816
# Delhi                  768
# Bangalore              767
# Ghaziabad              745
# Mumbai                 699
# Vadodara               694
# Varanasi               685
# Nagpur                 651
# Indore                 643
# Kanpur                 609
# Nashik                 547
# Faridabad              461
# Saanvi                   2
# Bhavna                   2
# City                     2
# Harsha                   2
# ...

# %%
df.loc[1:18:2,['Degree','Sleep Duration']]
# Out:
#       Degree     Sleep Duration
# 1        BSc          5-6 hours
# 3        BCA          7-8 hours
# 5        PhD  Less than 5 hours
# 7   Class 12  Less than 5 hours
# 9        LLB  Less than 5 hours
# 11        BE  Less than 5 hours
# 13  Class 12  Less than 5 hours
# 15    M.Tech  More than 8 hours
# 17  Class 12          5-6 hours

# %%
df.loc[1:18:2,'City':'CGPA']
# Out:
#          City Profession  Academic Pressure  Work Pressure  CGPA
# 1   Bangalore    Student                2.0            0.0  5.90
# 3    Varanasi    Student                3.0            0.0  5.59
# 5        Pune    Student                2.0            0.0  5.70
# 7     Chennai    Student                2.0            0.0  8.04
# 9      Nashik    Student                2.0            0.0  8.38
# 11   Vadodara    Student                3.0            0.0  7.03
# 13     Rajkot    Student                2.0            0.0  8.52
# 15   Srinagar    Student                3.0            0.0  8.58
# 17  Ahmedabad    Student                5.0            0.0  7.25

# %%
#WRITE A CODE TO FILTER A DATASET DF AND SELECT ROWS WHERE THE CITY COLUMN IS kalyan jaipur or delhi and then select only financial stress column from the filtered rows

# %%
df['Financial Stress'].filter('City' == 'Kalyan' | 'jaipur' | 'delhi')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df['Financial Stress'].filter('City' == 'Kalyan' | 'jaipur' | 'delhi')
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
